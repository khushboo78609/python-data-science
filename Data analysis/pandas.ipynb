# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/digipodium/Datasets/main/classfication/pokemon_type.csv'
df = pd.read_csv(url) # df is an object

# %%
df
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
# ...

# %%
pd.set_option('display.max_columns')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 pd.set_option('display.max_columns')
#
# File c:\Users\PUBLIC\miniconda3\Lib\site-packages\pandas\_config\config.py:272, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     271 def __call__(self, *args, **kwds) -> T:
# --> 272     return self.__func__(*args, **kwds)
#
# File c:\Users\PUBLIC\miniconda3\Lib\site-packages\pandas\_config\config.py:157, in _set_option(*args, **kwargs)
#     155 nargs = len(args)
#     156 if not nargs or nargs % 2 != 0:
# --> 157     raise ValueError("Must provide an even number of non-keyword arguments")
#     159 # default to false
#     160 silent = kwargs.pop("silent", False)
#
# ValueError: Must provide an even number of non-keyword arguments

# %%
df # dont display of using print() function
# Out:
#      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
# ...

# %%
df.head() # display first 5 rows
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      50  ...    Red       True    0.875     Monster       Dragon
# 4      65  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %%
df.head(10)
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
# 5       6   Charizard   Fire  Flying    534  78      84       78     109
# 6       7    Squirtle  Water     NaN    314  44      48       65      50
# 7       8   Wartortle  Water     NaN    405  59      63       80      65
# 8       9   Blastoise  Water     NaN    530  79      83      100      85
# 9      10    Caterpie    Bug     NaN    195  45      30       35      20
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Number        Name   Type_1  Type_2  Total   HP  Attack  Defense  Sp_Atk  \
# 0         1   Bulbasaur    Grass  Poison    318   45      49       49      65
# 1         2     Ivysaur    Grass  Poison    405   60      62       63      80
# 2         3    Venusaur    Grass  Poison    525   80      82       83     100
# 3         4  Charmander     Fire     NaN    309   39      52       43      60
# 4         5  Charmeleon     Fire     NaN    405   58      64       58      80
# ..      ...         ...      ...     ...    ...  ...     ...      ...     ...
# 716     717     Yveltal     Dark  Flying    680  126     131       95     131
# 717     718     Zygarde   Dragon  Ground    600  108     100      121      81
# 718     719     Diancie     Rock   Fairy    600   50     100      150     100
# 719     720       Hoopa  Psychic   Ghost    600   80     110       60     150
# 720     721   Volcanion     Fire   Water    600   80     110      120     130
#
# ...

# %%
df.describe(include=['object'])
# Out:
#              Name Type_1  Type_2 Color Egg_Group_1 Egg_Group_2      Body_Style
# count         721    721     350   721         721         191             721
# unique        721     18      18    10          15          13              14
# top     Bulbasaur  Water  Flying  Blue       Field      Dragon  bipedal_tailed
# freq            1    105      87   134         169          35             158

# %%
df['Name'] # series
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# Name: Name, Length: 721, dtype: object

# %%
df.Attack # series
# Out:
# 0       49
# 1       62
# 2       82
# 3       52
# 4       64
#       ...
# 716    131
# 717    100
# 718    100
# 719    110
# 720    110
# Name: Attack, Length: 721, dtype: int64

# %%
df[['Name', 'Attack']] # dataframe
# Out:
#            Name  Attack
# 0     Bulbasaur      49
# 1       Ivysaur      62
# 2      Venusaur      82
# 3    Charmander      52
# 4    Charmeleon      64
# ..          ...     ...
# 716     Yveltal     131
# 717     Zygarde     100
# 718     Diancie     100
# 719       Hoopa     110
# 720   Volcanion     110
#
# [721 rows x 2 columns]

# %%
cols = ['Name', 'Attack', 'Defense','Speed', 'HP']


df[cols] # dataframe
# Out:
#            Name  Attack  Defense  Speed   HP
# 0     Bulbasaur      49       49     45   45
# 1       Ivysaur      62       63     60   60
# 2      Venusaur      82       83     80   80
# 3    Charmander      52       43     65   39
# 4    Charmeleon      64       58     80   58
# ..          ...     ...      ...    ...  ...
# 716     Yveltal     131       95     99  126
# 717     Zygarde     100      121     95  108
# 718     Diancie     100      150     50   50
# 719       Hoopa     110       60     70   80
# 720   Volcanion     110      120     70   80
#
# [721 rows x 5 columns]

# %%
# listing all colums
df.columns.tolist()
# Out:
# ['Number',
#  'Name',
#  'Type_1',
#  'Type_2',
#  'Total',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp_Atk',
#  'Sp_Def',
#  'Speed',
#  'Generation',
#  'isLegendary',
#  'Color',
#  'hasGender',
#  'Pr_Male',
#  'Egg_Group_1',
#  'Egg_Group_2',
#  'hasMegaEvolution',
#  'Height_m',
#  'Weight_kg',
#  'Catch_Rate',
#  'Body_Style']

# %%
df[['Name', 'Attack']].head(25).plot(x='Name', y= 'Attack', kind='bar', figsize=(15,5))
# Out:
# <Axes: xlabel='Name'>

# %%
df[['Name','Attack','Defense']].head(25).plot(x='Name',y=['Attack',])
# Out:
# <Axes: xlabel='Name'>

# %% [markdown]
# row selection

# %%
df.loc[4] # 4 is taken as Label
# Out:
# Number                           5
# Name                    Charmeleon
# Type_1                        Fire
# Type_2                         NaN
# Total                          405
# HP                              58
# Attack                          64
# Defense                         58
# Sp_Atk                          80
# Sp_Def                          65
# Speed                           80
# Generation                       1
# isLegendary                  False
# Color                          Red
# hasGender                     True
# Pr_Male                      0.875
# Egg_Group_1                Monster
# Egg_Group_2                 Dragon
# hasMegaEvolution             False
# Height_m                      1.09
# Weight_kg                     19.0
# Catch_Rate                      45
# Body_Style          bipedal_tailed
# Name: 4, dtype: object

# %%
df.iloc[100] # 100 is taken as index
# Out:
# Number                    101
# Name                Electrode
# Type_1               Electric
# Type_2                    NaN
# Total                     480
# HP                         60
# Attack                     50
# Defense                    70
# Sp_Atk                     80
# Sp_Def                     80
# Speed                     140
# Generation                  1
# isLegendary             False
# Color                     Red
# hasGender               False
# Pr_Male                   NaN
# Egg_Group_1           Mineral
# Egg_Group_2               NaN
# hasMegaEvolution        False
# Height_m                 1.19
# Weight_kg                66.6
# Catch_Rate                 60
# Body_Style          head_only
# Name: 100, dtype: object

# %%
df.iloc[5:15] # 5:15 -> 10 rows
# Out:
#     Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 5        6   Charizard   Fire  Flying    534  78      84       78     109
# 6        7    Squirtle  Water     NaN    314  44      48       65      50
# 7        8   Wartortle  Water     NaN    405  59      63       80      65
# 8        9   Blastoise  Water     NaN    530  79      83      100      85
# 9       10    Caterpie    Bug     NaN    195  45      30       35      20
# 10      11     Metapod    Bug     NaN    205  50      20       55      25
# 11      12  Butterfree    Bug  Flying    395  60      45       50      90
# 12      13      Weedle    Bug  Poison    195  40      35       30      20
# 13      14      Kakuna    Bug  Poison    205  45      25       50      25
# 14      15    Beedrill    Bug  Poison    395  65      90       40      45
#
#     Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 5       85  ...     Red       True    0.875     Monster       Dragon
# ...

# %%
df.iloc[5:15, 2: 6] # 5:15 -. 10 rows and 2 to 5 columns
# Out:
#    Type_1  Type_2  Total  HP
# 5    Fire  Flying    534  78
# 6   Water     NaN    314  44
# 7   Water     NaN    405  59
# 8   Water     NaN    530  79
# 9     Bug     NaN    195  45
# 10    Bug     NaN    205  50
# 11    Bug  Flying    395  60
# 12    Bug  Poison    195  40
# 13    Bug  Poison    205  45
# 14    Bug  Poison    395  65

# %% [markdown]
# basic mathemetical operations
#
# ``````

# %%
print(df['Attack'].sum())
print(df['Attack'].mean())
print(df['Attack'].max(), '@',df['Attack'].argmax()) # a rgmax() returns index
print(df['Defense'].median())
# Out:
# 54085
# 75.01386962552012
# 165 @ 408
# 65.0

# %% [markdown]
# statistical operations on dataframe
#
# - df_var.corr(): correlation between columns
# - df_var.

# %%
df[['Attack', 'Defense','Speed','HP', 'Total']].corr()
# Out:
#            Attack   Defense     Speed        HP     Total
# Attack   1.000000  0.433233  0.335013  0.431680  0.704164
# Defense  0.433233  1.000000 -0.008663  0.228834  0.605831
# Speed    0.335013 -0.008663  1.000000  0.170031  0.548890
# HP       0.431680  0.228834  0.170031  1.000000  0.642628
# Total    0.704164  0.605831  0.548890  0.642628  1.000000

# %%
sns.replot(x='Attack', y = 'Defense', data=df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sns.replot(x='Attack', y = 'Defense', data=df)
#
# AttributeError: module 'seaborn' has no attribute 'replot'

# %%
df.count() # count the number of non-null values in each column
# Out:
# Number              721
# Name                721
# Type_1              721
# Type_2              350
# Total               721
# HP                  721
# Attack              721
# Defense             721
# Sp_Atk              721
# Sp_Def              721
# Speed               721
# Generation          721
# isLegendary         721
# Color               721
# hasGender           721
# Pr_Male             644
# Egg_Group_1         721
# Egg_Group_2         191
# hasMegaEvolution    721
# Height_m            721
# Weight_kg           721
# Catch_Rate          721
# Body_Style          721
# dtype: int64

# %%
df.select_dtypes(include='number').max() # select all numeric columns ṭhen find max
# Out:
# Number        721.0
# Total         720.0
# HP            255.0
# Attack        165.0
# Defense       230.0
# Sp_Atk        154.0
# Sp_Def        230.0
# Speed         160.0
# Generation      6.0
# Pr_Male         1.0
# Height_m       14.5
# Weight_kg     950.0
# Catch_Rate    255.0
# dtype: float64

# %% [markdown]
# dataframe manipulation
# - sorting
#   - df

# %%
df.sort_values(by='Attack').tail(10).plot(x='Name',y = ['Attack', 'Defense', 'Speed'],
                                          kind='bar',figsize=(15,5) )
# Out:
# <Axes: xlabel='Name'>
