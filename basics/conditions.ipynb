# %%
x = 10 
if x > 5:
    print('x is bigger than 5')
# Out:
# x is bigger than 5

# %%
x = 15
y = 13
if x < y:
    print('Answer will be negative')
    print(x-y)
print('Done')
# Out:
# Done

# %%
x = 21
if x % 2 == 0:
    print('X is an even number')
else:
    print('X is odd number')
# Out:
# X is odd number

# %%
# if loan amount > 500000 then rate = 3, else rate = 4

# %%
p = int(input('Enter loan amount:'))
if p > 500000:
    r = 3
else:
    r = 4
t = int(input('Enter loan tenure:'))
si = p * r * t/100 
(f'Simple interest is {si} with Interest Rate = {r}%')
# Out:
# 'Simple interest is 80000.0 with Interest Rate = 4%'

# %%
x = 10
if x > 10:
    y = 20
else:
    y = 5
print(x)
print(y)
# Out:
# 10
# 5

# %%
x = 11 
y= 20 if x > 10 else 5
print(x,y)
# Out:
# 11 20

# %%
grade = 'A'
if grade == 'O':
    print(" You got more than 90% marks")
elif grade == 'A':
    print("You got more than 75% marks")
elif grade == 'B':
    print("You got more than 60% marks")
elif grade == "C":
    print(" You got more than 50% marks")
elif grade == 'F':
    print("You failed")
# Out:
# You got more than 75% marks

# %%
# step 1: create a var for basic salary
bs = 59319.50
# write the condition

if bs>100000:
    print ("1st condition runs")
    bonus = .2*bs
    hra = .15 * bs
    da = .1* bs
elif bs > 75000:
    print("2nd condition runs")
    bonus = .1* bs
    hra = .08 *bs
    da = .05* bs
elif bs>50000 and  bs < 75000:
    print(" 3rd condition runs")
    bonus = .05*bs
    hra = .03*bs
    da = .02*bs
elif bs<50000:
    
    print("4th condition runs")
    bonus = .1 *bs
    hra = .05 * bs 
    da = .03*bs 

ts = bs + bonus + hra + da
print (f'{bs} + {hra} + {da} +{bonus} => {ts}')
# Out:
#  3rd condition runs
# 59319.5 + 1779.585 + 1186.39 +2965.9750000000004 => 65251.45

# %%
choice = input('what would you like to have ?')
match choice:
    case "burger"|"Burger":
        print("McDonalds burger cost Rs. 100")
        print("That is not an option")
    case "momos"| "samose":
        print(" momos cost Rs. 80")
        print(" It is a valid option")
    case"sandwich":
        print("Sandwich cost Rs. 150")
        print("Not available")
    case _:
        print("Invalid choice")
# Out:
#  momos cost Rs. 80
#  It is a valid option

# %%
#nested if 

#when if statement is present inside another if statement

if condition1:
    if condition2:
        block of code
# Out:
#   Cell In[1], line 7
#     block of code
#           ^
# SyntaxError: invalid syntax

# %%
uname = "ajay"
pwd = "tyu123"
cpwd = "tyu123"
email = "ajay111@gmail.com"
if len(uname) > 0 and len(uname) <= 50:
    if len(pwd) > 0 and len(pwd) <= 12 and uname not in pwd:
        if pwd == cpwd:
            if '@' in email and '.' in email:
                print("Your details are correct")
                print("You are registered")
                print("Successfully")
            else:
                print("Invalid email")
        else:
            print("Password do not match")
    else:
        print("Invalid password")
else:
    print("Invalid username")
# Out:
# Your details are correct
# You are registered
# Successfully
